# %%
import pandas as pd
from PIL import Image
import io

# %%
df = pd.read_parquet("data/raw_data/hf_handwritten/test.parquet")
df
# Out:
#                                                    text  \
# 0     assuredness " Bella Bella Marie " ( Parlophone...
# 1     I don't think he will storm the charts with th...
# 2     CHRIS CHARLES , 39 , who lives in Stockton-on-...
# 3     Become a success with a disc and hey presto ! ...
# 4     Tolch , as he is known in Tin Pan Alley , like...
# ...                                                 ...
# 2910           just dusty-grey but muddy , slimy even .
# 2911           the fake friend of the family , like the
# 2912     client's eyes , the dust of fake security , of
# 2913      the result being somehow as ineffective , not
# 2914      His voice was like his black and pin-stripe ,
#
#                                                   image
# 0     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 1     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 2     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 3     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# ...

# %%
# Select Image to be Displayed
img_byte = df.loc[0, "image"]["bytes"]

# Convert Image
img = Image.open(io.BytesIO(img_byte))
img.show()
