.\x02\xe1" \x8d\xfcNn\xfc\xc9}"\x04\x08_\x08\x08\x84\xdf\x85O\xe47r\x13\xfe\xb7\x84\xcf\xc2\x85\xc8c\xe1"\\\xc9\x85<\x94\x86R:\x81\xd4\xd4\nbQ\x03$D\xbeA4\x81\x9a\x84F\xe4"\x80\xca]\xe1J>\x0b_\xc9gr\x12\xfe |\x10\x1a\x01!\x10\x08\x8d\x88(i\x14\x91&4\x91\xb3@\x02\xf2\x90\xe17\xe1\x9d| 7\xfe\xe4>\xc1\xd0\x84\xaf\x04$\xfcA\xf8H\xfe@\xde\x84\xff5\xe1\xb3p!\xf2P\xb8\nWr%\x8f\xa4\xa1t\xa5\x84Pk\xaa\x17%$!\x01\xe4!\xd1\\\x81\xa0H\x93\x1a,\xca=\xe1\x8d|\x12\xbe\x92/\xe4$\xfcA\xf8 4\x02B \x10N\x14\x15\x13\x82\xfc.@\x08 \xdf$ g!\x84& \xc8;\xb9\xf1\'\xf7\t\x86\x93\xf0\x89\x9cH\xf8\x93\xf0\x81\xfc\x81\xbc\t\xff[\xc2o\xc2\x89 \x8f\x84\xabp%W\xf2P\x12J)\x86\xd0\xa4\xb3+4\xb5I\x03\xca\x03r\x92\x84\x00\xa2\xa24\xb5I\xb1\xc8=\xe1\x8d|\x12\xbe\x92/\xe4$\xfcA\xf8(\x80\xdc\x843\x11\x95&!\x81\x80\x08r\x12 \xfcK"H\x93\x10B (\xf2Nn\xfc\xc9\x03r\x15>\x91\xbb\xc2\x8d\xfc\x9f\x0b\xff 4\x82<\x14\xae\xc2\x1b\xb9\x90\xc7\x026\x84\x14-]Cj\xea4\xcd5\t\x8a\xdc%\x10B\x12\xb1)*B\xa8\xf3<\xc7\xa2|\x8f|\x12\xfe\x81|C\xf8(\x9c\xc8\'\x11\x11E\xa0\xa6&!6\xa8\x04B\xf8W"\xa0\x08BBBB@\x94\x1by\xe7O\x1e\x90\x9bp%\xdf\x13N\xe4\xff\\x@\x1e\nW\ ...

# %%
# ---- Select Image to be Displayed ----
img_byte = df_hw.loc[0, "image"]

# ---- Convert Image ----
img = Image.open(io.BytesIO(img_byte))
img.show()

# %% [markdown]
# # Printed Dataset

# %%
# ---- Load Data ----
df_p = pd.read_parquet("data/raw_data/printed/train-00001-of-00025-095e9ac2cb5f0f2f.parquet")
df_p
# Out:
#                                                     image             label
# 0       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  incommensurately
# 1       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...         Isotropic
# 2       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...          NITRATES
# 3       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...           Locales
# 4       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...         neodymium
# ...                                                   ...               ...
# 288979  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...         Lecturers
# 288980  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...        receipting
# 288981  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...              AYES
# 288982  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...          Outraged
# 288983  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...           SIMPSON
#
# [288984 rows x 2 columns]

# %%
# ---- Displaying Image ----
img_byte = df_p.loc[0, "image"]["bytes"]
img = Image.open(io.BytesIO(img_byte))
img.show()

# %% [markdown]
# # Description

# %%
df_hw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2915 entries, 0 to 2914
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2915 non-null   object
#  1   image   2915 non-null   object
# dtypes: object(2)
# memory usage: 45.7+ KB

# %%
from pathlib import Path
from IPython.display import display

root = Path('C:/Users/Shashwat Kumar/Desktop/CodeHub/Projects/Optical Character Recognition')
raw_data = root / 'data' / 'raw_data'

files = [
    raw_data/'hf_handwritten/train.parquet',
    
    raw_data/'printed/train-00000-of-00025-e0800a94f785d368.parquet',
    raw_data/'printed/train-00001-of-00025-095e9ac2cb5f0f2f.parquet',
    raw_data/'printed/train-00002-of-00025-fb450bf0c15eb4b9.parquet',
    raw_data/'printed/train-00003-of-00025-3303678227724cd0.parquet',
    raw_data/'printed/train-00004-of-00025-93158a416467d85f.parquet',
    raw_data/'printed/train-00005-of-00025-0b57df213bf40375.parquet'
]

dfs = []

for path in files:
    print("\n---------- File: ", path.name, "----------")
    df = pd.read_parquet(path)
    dfs.append(df)
    display(df.head())
# Out:
# ---------- File:  train.parquet ----------
#                                        text  \
# 0      put down a resolution on the subject
# 1        and he is to be backed by Mr. Will
# 2     nominating any more Labour life Peers
# 3       M Ps tomorrow. Mr. Michael Foot has
# 4  Griffiths, M P for Manchester Exchange .
#
#                                                image
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# ---------- File:  train-00000-of-00025-e0800a94f785d368.parquet ----------
#                                                image            label
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...             Lube
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       Spencerian
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  accommodatingly
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...        CARPENTER
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    REGURGITATING
# ---------- File:  train-00001-of-00025-095e9ac2cb5f0f2f.parquet ----------
#                                                image             label
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  incommensurately
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...         Isotropic
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...          NITRATES
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...           Locales
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...         neodymium
# ---------- File:  train-00002-of-00025-fb450bf0c15eb4b9.parquet ----------
#                                                image          label
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     TRAGICOMIC
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       ROOMFULS
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...        Sucking
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      REVENGING
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  Incrustations
# ---------- File:  train-00003-of-00025-3303678227724cd0.parquet ----------
#                                                image      label
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...        Cob
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  BINDERIES
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     Vegged
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  ductility
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    Cayugas
# ---------- File:  train-00004-of-00025-93158a416467d85f.parquet ----------
#                                                image      label
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     Weaves
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    unlaced
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    stayers
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  BRASSIEST
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  described
# ---------- File:  train-00005-of-00025-0b57df213bf40375.parquet ----------
#                                                image      label
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  Blowtorch
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    Disowns
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     cretin
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    ROGERED
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      Quasi

# %%
print(dfs)
# Out:
# [                                                   text  \
# 0                  put down a resolution on the subject
# 1                    and he is to be backed by Mr. Will
# 2                 nominating any more Labour life Peers
# 3                   M Ps tomorrow. Mr. Michael Foot has
# 4              Griffiths, M P for Manchester Exchange .
# ...                                                 ...
# 6477      beside # Catherine . She had the stories open
# 6478            In the train going back to London I sat
# 6479      I wish I went to that school . Did you notice
# 6480    that girl who said hullo to him in the garden ?
# 6481  in front of her , but she said : ' Philip 's a...
#
#                                                   image
# 0     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 1     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 2     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 3     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 4     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# ...                                                 ...
# 6477  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 6478  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 6479  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 6480  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 6481  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
#
# [6482 rows x 2 columns],                                                     image            label
# 0       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...             Lube
# 1       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       Spencerian
# 2       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  accommodatingly
# 3       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...        CARPENTER
# 4       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    REGURGITATING
# ...                                                   ...              ...
# 288979  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       ASYMPTOTIC
# 288980  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...           Virgie
# 288981  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     unscrambling
# 288982  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...          LINSEED
# 288983  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...        Spacewalk
#
# [288984 rows x 2 columns],                                                     image             label
# 0       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  incommensurately
# 1       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...         Isotropic
# 2       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...          NITRATES
# 3       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...           Locales
# 4       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...         neodymium
# ...                                                   ...               ...
# 288979  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...         Lecturers
# 288980  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...        receipting
# 288981  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...              AYES
# 288982  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...          Outraged
# 288983  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...           SIMPSON
#
# [288984 rows x 2 columns],                                                     image          label
# 0       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     TRAGICOMIC
# 1       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       ROOMFULS
# 2       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...        Sucking
# 3       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      REVENGING
# 4       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  Incrustations
# ...                                                   ...            ...
# 288979  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       Rollmops
# 288980  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...            Apo
# 288981  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       Mouthful
# 288982  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...         Armand
# 288983  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...        PARRIES
#
# [288984 rows x 2 columns],                                                     image        label
# 0       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...          Cob
# 1       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    BINDERIES
# 2       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       Vegged
# 3       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    ductility
# 4       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      Cayugas
# ...                                                   ...          ...
# 288979  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  ENTHRALLING
# 288980  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    neoplasms
# 288981  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...          Edt
# 288982  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     mistypes
# 288983  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       Preppy
#
# [288984 rows x 2 columns],                                                     image       label
# 0       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      Weaves
# 1       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     unlaced
# 2       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     stayers
# 3       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...   BRASSIEST
# 4       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...   described
# ...                                                   ...         ...
# 288979  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     baggier
# 288980  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       UMBRA
# 288981  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     Secants
# 288982  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  COMMANDEER
# 288983  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    UNEVENLY
#
# [288984 rows x 2 columns],                                                     image       label
# 0       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...   Blowtorch
# 1       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     Disowns
# 2       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      cretin
# 3       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...     ROGERED
# 4       {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...       Quasi
# ...                                                   ...         ...
# 288979  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    INDIRECT
# 288980  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    EMULATES
# 288981  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...   unbosomed
# 288982  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  crankcases
# 288983  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    LEAFLETS
#
# [288984 rows x 2 columns]]

# %%
for i, obj in enumerate(dfs):
    print(i, type(obj), getattr(obj, "shape", None))
# Out:
# 0 <class 'pandas.core.frame.DataFrame'> (6482, 2)
# 1 <class 'pandas.core.frame.DataFrame'> (288984, 2)
# 2 <class 'pandas.core.frame.DataFrame'> (288984, 2)
# 3 <class 'pandas.core.frame.DataFrame'> (288984, 2)
# 4 <class 'pandas.core.frame.DataFrame'> (288984, 2)
# 5 <class 'pandas.core.frame.DataFrame'> (288984, 2)
# 6 <class 'pandas.core.frame.DataFrame'> (288984, 2)

# %%
df0 = pd.read_parquet(raw_data/'hf_handwritten/train.parquet')
df1 = pd.read_parquet(raw_data/'printed/train-00000-of-00025-e0800a94f785d368.parquet')

# %%
def has_extra_meta(v):
    return isinstance(v, dict) and any(k != "bytes" for k in v)

# DF #1
img0 = df0.loc[0, "image"]
print("DF #1 type:", type(img0))
if isinstance(img0, dict):
    print("DF #1 keys:", list(img0.keys()))
print("DF #1 has extra metadata?", has_extra_meta(img0))

# DF #2
img1 = df1.loc[0, "image"] 
print("DF #2 type:", type(img1))
if isinstance(img1, dict):
    print("DF #2 keys:", list(img1.keys()))
print("DF #2 has extra metadata?", has_extra_meta(img1))
# Out:
# DF #1 type: <class 'dict'>
# DF #1 keys: ['bytes', 'path']
# DF #1 has extra metadata? True
# DF #2 type: <class 'dict'>
# DF #2 keys: ['bytes', 'path']
# DF #2 has extra metadata? True

# %% [markdown]
# # Concatenating Data

# %%
hand_files = [p for p in files if "hf_handwritten" in str(p)]
print_files = [p for p in files if "printed" in str(p)]

def concat

# %%
# ---- Standardizing all datafarmes ----

def standardize_col(df: pd.DataFrame) -> pd.DataFrame:
    """
    Reorder columns of all dataframes in ['text', 'image'] format in order to 
    maintain consistency and prevent conflicts during concatenation of dataframes.
    """
    df = df.copy()
    df.columns = [str(c).lower().strip() for c in df.columns]

    if {"image", "label"}.issubset(df.columns):
        df = df.rename(columns = {"label": "text"})
    elif {"text", "image"}.issubset(df.columns):
        pass
    else:
        raise ValueError(f"Unexpected columns: {list(df.columns)}; need ['image', 'label'] or ['text', 'image'].")

    df = df[["text", "image"]]
    df["text"] = df["text"].astype("string")
    return df

df_std = []
df_std_handwritten = []
df_std_printed = []

for path in files:
    df = pd.read_parquet(path)
    df = standardize_col(df)
    df_std.append(df)

    path_str = str(path)
    if "printed" in path_str:
        df_std_printed.append(df)
    elif "hf_handwritten" in path_str:
        df_std_handwritten.append(df)

data_raw = pd.concat(df_std, ignore_index = True)

printed_data = (a
    pd.concat(df_std_printed, ignore_index=True)
    if df_std_printed
    else data_raw.iloc[0:0].copy()
)

handwritten_data = (
    pd.concat(df_std_handwritten, ignore_index=True)
    if df_std_handwritten
    else data_raw.iloc[0:0].copy()
)

# %%
data_raw.head()
# Out:
#                                        text  \
# 0      put down a resolution on the subject
# 1        and he is to be backed by Mr. Will
# 2     nominating any more Labour life Peers
# 3       M Ps tomorrow. Mr. Michael Foot has
# 4  Griffiths, M P for Manchester Exchange .
#
#                                                image
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...

# %%
printed_data.head()
# Out:
#               text                                              image
# 0             Lube  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 1       Spencerian  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 2  accommodatingly  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 3        CARPENTER  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 4    REGURGITATING  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...

# %%
handwritten_data
# Out:
#                                                    text  \
# 0                  put down a resolution on the subject
# 1                    and he is to be backed by Mr. Will
# 2                 nominating any more Labour life Peers
# 3                   M Ps tomorrow. Mr. Michael Foot has
# 4              Griffiths, M P for Manchester Exchange .
# ...                                                 ...
# 6477      beside # Catherine . She had the stories open
# 6478            In the train going back to London I sat
# 6479      I wish I went to that school . Did you notice
# 6480    that girl who said hullo to him in the garden ?
# 6481  in front of her , but she said : ' Philip 's a...
#
#                                                   image
# 0     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 1     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 2     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 3     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 4     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# ...                                                 ...
# 6477  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 6478  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 6479  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 6480  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 6481  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
#
# [6482 rows x 2 columns]

# %%
data_raw.loc[0, 'image']
# Out:
# {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\